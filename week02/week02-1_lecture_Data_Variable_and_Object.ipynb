# %% [markdown]
# # NTUEE Computer Programming
# # Week2 - Data, Variables & Object
# <div style="color:#999999;text-align:right;">Ref: <a href="https://greenteapress.com/wp/think-python/">Think Python</a> &ensp; <a href="https://learnpythonthehardway.org">Learn Python the Hard Way</a></div>

# %% [markdown]
# ## Slides: What is data? (p2.)
# ### Example: Image Data
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Slides: What can computers do? (p3.)

# %%
# simple math computing
3*5
# Out:
# 15

# %%
# complex math computing
import math
print(pow(3.14, 3.14)) # 3.14^3.14
print(math.factorial(100)) # 100!
# Out:
# 36.33783888017471
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
# Word processing
s = 'Hello world'
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## Slides: Data Type (Integer number) (p.12)

# %%
x = 3
print(type(x))

x = 3.14159      #改變x資料型態
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>

# %%
x = 3.14159
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# ## Slides: Data Type (Floating point number) (p.13)

# %%
y = -4.17391338516e-21
print(type(y))
# Out:
# <class 'float'>

# %% [markdown]
# ## Slides: Data Type (String) (p.14)

# %%
z = 'python'
print(type(z))
# Out:
# <class 'str'>

# %% [markdown]
# ## Slides: Declare variable in Python (p.23)

# %%
a = 10
print(type(a))
b = 3.14
print(type(b))
s = 'python'
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## Slides: Declare variable (p.24)

# %%
X = 777   
Y = 777

print(id(X))
print(id(Y))

print(X is Y)     #比較記憶體空間 (id)
print(X == Y)     #比較記憶體裡面儲存的value (777)

print(X = Y)
# Out:
# 4400394192
# 4400394160
# False
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/maaa/Library/CloudStorage/Dropbox-個人/2023_programming/python2023fall/week02_data_variable_object/week02_lecture_Data_Variable_and_Object.ipynb Cell 17 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/Users/maaa/Library/CloudStorage/Dropbox-%E5%80%8B%E4%BA%BA/2023_programming/python2023fall/week02_data_variable_object/week02_lecture_Data_Variable_and_Object.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> print(X is Y)     #比較記憶體空間 (id)
#       <a href='vscode-notebook-cell:/Users/maaa/Library/CloudStorage/Dropbox-%E5%80%8B%E4%BA%BA/2023_programming/python2023fall/week02_data_variable_object/week02_lecture_Data_Variable_and_Object.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> print(X == Y)     #比較記憶體裡面儲存的value (777)
# ...

# %%
x = 777
print(id(x))   #python幫x分配的記憶體空間
# Out:
# 4400393072

# %% [markdown]
# ## Slides: What is Object (p.30)

# %%
x = 'python'
print(type(x))
# Out:
# <class 'str'>

# %%
s = 'python'
print(dir(s))   #列出所有object可以使用的class與method
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
s.upper()   # dot operator
# Out:
# 'PYTHON'

# %%
# Get attribute
s = 'python' 
print(s.__class__)
# Out:
# <class 'str'>

# %%
# Use method
s = 'python'
print(s.upper())
# Out:
# PYTHON

# %% [markdown]
# Use help() to watch the description

# %%
s = 'python'
help(s.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
s = 'python'
print(help(type(s)))
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %% [markdown]
# ## Exercise: Find the attributes and methods for floating points (p.33)

# %%
a = 3.14
print(dir(a))
# Out:
# ['__abs__', '__add__', '__bool__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getformat__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__int__', '__le__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__pos__', '__pow__', '__radd__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__set_format__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', 'as_integer_ratio', 'conjugate', 'fromhex', 'hex', 'imag', 'is_integer', 'real']

# %% [markdown]
# ## Slides: Object for Python - Example (p.35)

# %%
x = 777
print(id(x))        #印出x的記憶體位址
print(hex(id(x)))   #轉成16進位
# Out:
# 4412658224
# 0x10703d230

# %%
x = 777
y = 'bbb'
print(hex(id(x)))
print(hex(id(y)))
# Out:
# 0x7feac4208150
# 0x7feacb02a730

# %%
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Slides: Different Types, different attributes (p.36)

# %%
x = 777
y = 'bbb'
print(dir(x))
print(dir(y))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ...

# %% [markdown]
# ## Slides: Everything is an object! (p.37-38)
# Build-in functions are objects, too:

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
print(dir(print))
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']

# %%
import math
type(math)
# Out:
# module

# %%
print(dir(math))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
x = 2
y = 3
print(pow(x,y))    #math套件裡面的pow函式(次方)
# Out:
# 8

# %% [markdown]
# ## Slides: Arithmetic Operators (p.42)

# %%
print(25 + 30 / 6)
print(100 - 25 * 3 % 4)
print(3+2+1-5+ 6%2- 1/4+ 6)
# Out:
# 30.0
# 97
# 6.75

# %% [markdown]
# ## Slides: Assignment Operator (p.43)

# %%
a = 2
a += 3
print (a)

a = a + 3
print (a)
# Out:
# 5
# 8

# %%
a = 5
a += 6
print(a)
a *= 7
print(a)
a %= 4
print(a)
# Out:
# 11
# 77
# 1

# %% [markdown]
# ## Slides: Comparison Operators (p.44)

# %%
a = 5
b = 6
print(a == b)
print(a <= b)
print(a >= b)
# Out:
# False
# True
# False

# %% [markdown]
# ## Slides: Logical Operators (p.45)

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not b)
# Out:
# False
# True
# True

# %% [markdown]
# ## Slides: Bitwise Operators (p.46)

# %%
a = 6   # 00000110
b = 5   # 00000101
print(a & b)
print(a | b)
print(a ^ b)
print(~a)
print(a << 1)
print(a >> 1)
# Out:
# 4
# 7
# 3
# -7
# 12
# 3

# %% [markdown]
# ## Slides: Identity operators (p.47)

# %%
a = 10101
b = 10101
c = a
print(a is b)
print(a is c)
# Out:
# False
# True

# %% [markdown]
# ## Slides: Dot operators (p.48)

# %%
s = 'python'
s.upper()
# Out:
# 'PYTHON'

# %%
#指數運算從右至左

print(4 ** 2 ** 2)   #(4^(2^(2)))
# Out:
# 256

# %% [markdown]
# ## Slides: Polymorphism (p.51)

# %%
print(1 + 1)         #operator作為“整數運算”運算子
print('ab' + 'cd')   #operator作為“字串運算”運算子
# Out:
# 2
# abcd
